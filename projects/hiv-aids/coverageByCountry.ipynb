# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/art_coverage_by_country_clean.csv')

# %%
df.head()
# Out:
#        Country Reported number of people receiving ART  \
# 0  Afghanistan                                     920
# 1      Albania                                     580
# 2      Algeria                                   12800
# 3       Angola                                   88700
# 4    Argentina                                   85500
#
#   Estimated number of people living with HIV  \
# 0                           7200[4100–11000]
# 1                                     Nodata
# 2                         16000[15000–17000]
# 3                      330000[290000–390000]
# 4                      140000[130000–150000]
#
#   Estimated ART coverage among people living with HIV (%)  \
# 0                                           13[7–20]
# 1                                             Nodata
# 2                                          81[75–86]
# 3                                          27[23–31]
# 4                                          61[55–67]
#
# ...
