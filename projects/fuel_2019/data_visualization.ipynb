# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
price_by_state_df = pd.read_csv('datasets/price_by_state.csv', sep=';', index_col=0)

# %%
price_by_state_df
# Out:
#                 DIESEL  DIESEL S10  ETANOL  GASOLINA   GNV
# Estado - Sigla
# AC                4.43        4.50    4.02      4.92  0.00
# AL                3.75        3.82    3.56      4.58  3.43
# AM                3.76        3.86    3.41      4.30  3.17
# AP                4.12        4.61    3.83      3.97  0.00
# BA                3.58        3.66    3.46      4.57  3.14
# CE                3.78        3.81    3.67      4.54  3.56
# DF                3.71        3.83    3.28      4.28  3.28
# ES                3.53        3.62    3.61      4.47  3.30
# GO                3.57        3.70    2.99      4.50  3.89
# MA                3.63        3.66    3.73      4.36  3.60
# MG                3.60        3.71    3.09      4.72  3.52
# MS                3.61        3.72    3.45      4.20  2.92
# MT                3.92        3.98    2.65      4.48  3.70
# PA                3.86        3.89    3.86      4.61  0.00
# PB                3.58        3.62    3.27      4.24  3.72
# PE                3.67        3.55    3.39      4.36  2.77
# PI                3.64        3.72    3.49      4.57  0.00
# PR                3.35        3.43    2.97      4.25  3.15
# RJ                3.54        3.69    3.80      4.87  3.20
# RN                3.63        3.77    3.50      4.41  3.56
# RO                3.79        3.88    3.95      4.56  0.00
# RR                3.58        3.65    3.76      4.09  0.00
# RS                3.45        3.59    4.11      4.57  3.41
# SC                3.43        3.55    3.56      4.12  2.91
# SE                3.57        3.68    3.51      4.39  3.69
# SP                3.43        3.55    2.74      4.16  2.89
# TO                3.56        3.61    3.74      4.55  3.50

# %%
fig, ax = plt.subplots(figsize=(15,15))
sea.heatmap(price_by_state_df, linewidths=0.10, linecolor='gray', cmap="mako_r", annot=True, annot_kws={"fontsize":14}, ax=ax, fmt="f")
title = plt.figtext(.5,.9,"Preço médio do combustível por tipo e estado (Em R$) - 1° Sem 2019", fontsize=18, ha="center")
title.set_position([.5, 0.92])
ax.xaxis.set_label_text("Tipo de combustível", fontdict={'size':18})
ax.yaxis.set_label_text("Estado", fontdict={'size':18})
# Out:
# Text(114.0, 0.5, 'Estado')

# %%
fig.savefig('images/fuel2019.jpg')
