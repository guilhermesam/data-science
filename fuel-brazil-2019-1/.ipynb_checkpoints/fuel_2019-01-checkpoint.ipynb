# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea
import chardet

# %%
# Manipulação do dataframe
df = pd.read_csv("gasolina.csv", encoding="Windows-1252", delimiter=';')
df["Valor de Compra"].fillna("Indefinido",inplace=True) # preenche valores null com "Indefinido"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-a4f4d71b9a6b> in <module>
#       1 # Manipulação do dataframe
# ----> 2 df = pd.read_csv("gasolina.csv", encoding="Windows-1252", delimiter=';')
#       3 df["Valor de Compra"].fillna("Indefinido",inplace=True) # preenche valores null com "Indefinido"
#
# ...

# %%
# Checando as propriedades do arquivo csv
with open("gasolina.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))

print(result)

# %%
fuel = pd.DataFrame()
for state in list(df["Estado - Sigla"].unique()):
    for product in list(df["Produto"].unique()):
        price = df[(df["Estado - Sigla"] == state) & (df["Produto"] == product)]["Valor Venda"].mean()
        fuel = fuel.append(pd.DataFrame({'Estado':state , 'Produto':product , 'Valor de Venda':price}, index=[0]))
fuel = fuel.reset_index()
del fuel['index']
fuel["Valor de Venda"].fillna(0,inplace=True) # preenche valores null com 0
fuel["Valor de Venda"].isnull().value_counts() 
fuel["Valor de Venda"] = fuel["Valor de Venda"].astype(float)
fuel.head()
# Out:
#   Estado     Produto  Valor de Venda
# 0     DF      DIESEL        3.704437
# 1     DF  DIESEL S10        3.833805
# 2     DF      ETANOL        3.276517
# 3     DF    GASOLINA        4.275471
# 4     DF         GNV        3.279250

# %%
gas = fuel.pivot("Estado", "Produto", "Valor de Venda")
fig, ax = plt.subplots(figsize=(15,15))
sea.heatmap(gas, linewidths=1, cmap="YlGnBu", annot=True, ax=ax, fmt="f")
ax.set_title("Heatmap - Preço médio do combustível por tipo e estado (Em R$)",fontdict={'size':20})
ax.xaxis.set_label_text("Tipo de combustível",fontdict= {'size':20})
ax.yaxis.set_label_text("Estado",fontdict= {'size':20})
plt.show()

# %%
fig.savefig("fuel.png")
